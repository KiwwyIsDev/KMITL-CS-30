# %%
# Q2
import requests, json

url = "https://online-movie-database.p.rapidapi.com/auto-complete"

query = {"q": "dead p"}

headers = {
    "x-rapidapi-key": "ccff853f45mshca622d12d5d65fdp1020bajsncca6b5d32221",
    "x-rapidapi-host": "online-movie-database.p.rapidapi.com",
}

res = requests.get(url, headers=headers, params=query)

# print(res.json())
# res = json.loads(res.text)
# resformat = json.dumps(res, indent=4)
# print(resformat)

for movie in res.json()["d"]:
  print(movie["l"])
# Out:
# Dead Poets Society
# Mission: Impossible - Dead Reckoning Part One
# Mission: Impossible 8
# Dead Presidents
# Pirates of the Caribbean: Dead Man's Chest
# The Dead Pool
# Pirates of the Caribbean: Dead Men Tell No Tales
# Play Dead

# %%
#Q3
import requests, json

headers = {"api-key": "ZswohoVvnFmxIxbh7dixxKhUtZO2RaYe"}
res = requests.get("https://opend.data.go.th/get-ckan/datastore_search?resource_id=1c2f6045-c600-410a-995c-a37a88594ab4&limit=5"
                   ,headers=headers)

# print(res.json())

resformat = json.dumps(json.loads(res.text), indent=4, ensure_ascii=False)
print(resformat)
# Out:
# {
#     "help": "https://data.go.th/api/3/action/help_show?name=datastore_search",
#     "success": true,
#     "result": {
#         "include_total": true,
#         "limit": 5,
#         "records_format": "objects",
#         "resource_id": "1c2f6045-c600-410a-995c-a37a88594ab4",
#         "total_estimation_threshold": null,
#         "records": [
#             {
#                 "_id": 1,
#                 "No.": 1859158,
#                 "announce_date": "2021-10-26T00:00:00",
#                 "Notified date": "2021-10-25T00:00:00",
#                 "sex": "ชาย",
#                 "age": 20,
#                 "Unit": "ปี",
#                 "nationality": "Thailand",
#                 "province_of_isolation": "ลำปาง",
#                 "risk": "อื่นๆ",
#                 "province_of_onset": "ลำปาง",
#                 "district_of_onset": "เมืองลำปาง"
#             },
#             {
#                 "_id": 2,
#                 "No.": 1859159,
# ...
